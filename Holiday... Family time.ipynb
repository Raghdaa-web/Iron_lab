# %% [markdown]
#                                         # Holiday Time

# %%
user_name = input("my name is: ")
# Out:
# my name is: Raghdaa

# %% [markdown]
# ![Raghdaa.png](attachment:Raghdaa.png)

# %% [markdown]
# ![paris.avif](attachment:paris.avif)

# %% [markdown]
# - Visit a new destination
#  - meet new people
#  - eating Icecream

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ayZIC9ATAZw" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ayZIC9ATAZw"</iframe>

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ayZIC9ATAZw"</iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ayZIC9ATAZw"</iframe>
